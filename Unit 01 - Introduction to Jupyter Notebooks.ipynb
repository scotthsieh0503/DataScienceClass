# %% [markdown]
# This is a Jupyter Notebook, formerly called an iPython Notebook.
# As seen in the prep course, these notebooks contain blocks that we can add code to.  Any code run in a block will be remembered in future blocks (until you restart).
#
# A block like this one is set to `Markdown`.  There is a dropdown menu under the Widgets menu at the top which allows you to change the *type* of block you have currently selected.  The main two types we will be using are `Code` and `Markdown`.
#
# We run a block of code by using CTRL-ENTER, or SHIFT-ENTER.  The latter will automatically select the next block in the sequence; this is handy if you want to run a number of blocks in sequence.  We can add a new block through the Insert dropdown menu above, or by pressing B when selecting a cell (but not the text inside the cell; the colour to the side should change from green to blue when the cell is selected, but you're not in editing mode).
#
# If you encounter a `Markdown` block, you can edit it by double clicking it.

# %% [markdown]
# x = 5
# x

# %% [markdown]
# This is what a Markdown cell looks like before we run it.  We can edit text, **bold**, *italics*, and even add $\LaTeX$.  Full line equations can go between double dollar signs:
# $$[v]\mapsto (v-\mathsf{s}_V(v))\circ 0_h;\quad v\in V_{\mathfrak{t}_H(h)}. $$
# We have access to basically the entire functionality of LaTeX:
# $$    \begin{matrix}
#     V & \rightrightarrows & V^{(0)} \\
#     \downarrow &  & \downarrow \\
#     H & \rightrightarrows & H^{(0)}
#     \end{matrix} $$
#
# Run this cell to display the text properly.

# %% [markdown]
# # Headers are made with single pound signs.
# ## Sub-headers are made by adding more pound signs.
# ### Functionally, we can go to three pound signs.
# #### At this point, we're basically writing bold text.
# ** Bold text**.
#
# Run this block as well.

# %%
# This block has code in it.
x = 7

# %%
# Since we ran the code in the previous block (we can see the " In [1]: ", telling us 
# when that block was run compared to the others), this block will remember.
# Any code that has an output will have it displayed below the block, with the "Out[ ]:" section
x
# Out:
# 7

# %% [markdown]
# The notebooks are also extremely handy for visualization, as we will see towards the middle of the course:

# %%
import matplotlib.pyplot as plt
# %pylab inline
pylab.rcParams['figure.figsize'] = (12.0, 10.0)

from mpl_toolkits.mplot3d import Axes3D
from matplotlib import pyplot as plt
import numpy as np


fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Create the mesh in polar coordinates and compute corresponding Z.
r = np.linspace(0, 1.25, 50)
p = np.linspace(0, 2*np.pi, 50)
R, P = np.meshgrid(r, p)
Z = ((R**2 - 1)**2)

# Express the mesh in the cartesian system.
X, Y = R*np.cos(P), R*np.sin(P)

# Plot the surface.
ax.plot_surface(X, Y, Z, cmap=plt.cm.magma)

# Tweak the limits and add latex math labels.
ax.set_zlim(0, 1)
ax.set_xlabel(r'$\phi_\mathrm{real}$')
ax.set_ylabel(r'$\phi_\mathrm{im}$')
ax.set_zlabel(r'$V(\phi)$')

plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# If you want to clear all of the code from the notebook to run things anew, you can select the Kernel menu above, and then click "Restart".  This will wipe clean all of the things the computer remembers about the code you wrote.

# %%
# Out:
# 7
